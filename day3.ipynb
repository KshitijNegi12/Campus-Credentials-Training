# %%
#list in python
  #insertion ordered preserved
  #duplicate values are allowed

# creation of list
l=[]
print(type(l))
l=[1,2,'a','s']

#dynamic input
l2=eval(input("enter list:"))   #by default input is in form tuple, we can take input with [1,2,300] or {1,2,3}
print(l2)

#list function
l=list(range(11,1,-2))
print(l)
# Out:
# <class 'list'>
# enter list1,2,3,4
# (1, 2, 3, 4)
# [11, 9, 7, 5, 3]

# %%
s="himanshu pandey"
print(s.split())
l=list(s)
print(l)
# Out:
# ['himanshu', 'pandey']
# ['h', 'i', 'm', 'a', 'n', 's', 'h', 'u', ' ', 'p', 'a', 'n', 'd', 'e', 'y']

# %%
#access elements
li=[11,22,33,444]
print("index 1 element",li[1])
print("last element",li[-1])
# Out:
# index 1 element 22
# last element 444

# %%
#list are mutalble
n=[1,2,3,44]
n[1]=22
print(n)
# Out:
# [1, 22, 3, 44]

# %%
#traversing
n=[1,2,3,4,5,67]
i=0
print("using while loop")
while i<len(n):
   print(n[i])
   i+=1
print("using for loop")
for i in n:
   print(i)
# Out:
# using while loop
# 1
# 2
# 3
# 4
# 5
# 67
# using for loop
# 1
# 2
# 3
# 4
# 5
# 67

# %%
#list functions
#len(length of list),count(occurance of elements),append(add data at the end),insert(add data at the specific position)

li=[1,2,3,1,3,1]
print(len(li))
print("count no of element occured:",li.count(1))

li.append(123)
li.append("A")
li.append(3.5)
print("append data:",li)

li.insert(2,"hello")
print("append data at index 2:",li)

#extend(add data of one list to another)
order1=[1,2,3]
order2=[4,5,6]
order1.extend(order2)
print("order1 and order2 are extended:",order1)

#remove(it removes the first occurance present in the list)
l2=[1,2,3,4,1,2]
l2.remove(1)
print(l2)
l2.remove(1)
print(l2)

#pop(remove last element)
n=[10,20,30,40]
print("last element is removed:",n.pop())
print(n)
# Out:
# 6
# count no of element occured: 3
# append data: [1, 2, 3, 1, 3, 1, 123, 'A', 3.5]
# append data at index 2: [1, 2, 'hello', 3, 1, 3, 1, 123, 'A', 3.5]
# order1 and order2 are extended: [1, 2, 3, 4, 5, 6]
# [2, 3, 4, 1, 2]
# [2, 3, 4, 2]
# last element is removed: 40
# [10, 20, 30]

# %%
#sort
n=[2,1,2,3,4,53,2,33,45]
n.sort()
print(n)

#reverse
n.reverse()
print(n)
# Out:
# [1, 2, 2, 2, 3, 4, 33, 45, 53]
# [53, 45, 33, 4, 3, 2, 2, 2, 1]

# %%
#mathematical operator
a=[12,23,24]
b=[1,2,3]
c=a+b
print("addition of a+b:",c)
d=a*3
print("3 copies of a:",d)

#empty list
n.clear()
print(n)
# Out:
# addition of a+b: [12, 23, 24, 1, 2, 3]
# 3 copies of a: [12, 23, 24, 12, 23, 24, 12, 23, 24]
# []

# %%
#nested list
n=[10,20,[30,40],[50,60,70]]
print(n[2][1])
print(n[3][0])
print(n)
# Out:
# 40
# 50
# [10, 20, [30, 40], [50, 60, 70]]

# %%
#nested list as a matrix
n=[[10,20,30],[40,50,60],[70,80,90]]
print(n)
for x in n:
  print(x)

for i in range(len(n)):
  for j in range(len(n[i])):
    print(n[i][j],end=" ")
  print()
# Out:
# [[10, 20, 30], [40, 50, 60], [70, 80, 90]]
# [10, 20, 30]
# [40, 50, 60]
# [70, 80, 90]
# 10 20 30
# 40 50 60
# 70 80 90

# %%
num=int(input("enter no of sem:"))
sem=[]
for i in range(num):

    sem[i]=input("ENTER NO OF SUBJECT IN SEM ",i)
marks=[][]
for i in sem:
  for j in
    marks[i][]

print(sem)
# Out:
# [[50, 60, 70], [90, 98, 60, 70]]
# max marks in sem1
# max marks in sem1
# max marks in sem1
# max marks in sem2
# max marks in sem2
# max marks in sem2
# max marks in sem2
# [3, 4]

# %%
#tuples
t=(10,20,30,40)
print(type(t))
print(t)
# Out:
# <class 'tuple'>
# (10, 20, 30, 40)

# %%
T=(10,20,30,40,10)
print(T.index(10))
print(T.count(10))
t1=sorted(T)
print(t1)m
# Out:
# 0
# 2
# [10, 10, 20, 30, 40]

# %%
#min and max
# print(min(t))
# print(max(t))
# print(sum(t))
t1=(3,4,5,6)
# print(cmp(t1,t))
print(len(t1))
# Out:
# 4

# %%
t=eval(input("enter no"))
print(type(t))
sum=0
avg=0

for i in range(len(t)):
  sum+=t[i]
avg=sum/len(t)

print("sum:",sum,"avg:",avg)
# Out:
# enter no1,2,3
# <class 'tuple'>
# sum: 6 avg: 2.0

# %%
#set

s={10,20,30,40}
print(type(s))
print(s)

s.add(50)

s2=s.copy()
print(s2)
s.pop()
print(s)

s.remove(50)
print(s)
print(s.clear())
# Out:
# <class 'set'>
# {40, 10, 20, 30}
# {50, 20, 40, 10, 30}
# {10, 50, 20, 30}
# {10, 20, 30}
# None

# %%
#dictionary
#duplicate keys are not allowed but values can be duplicate
#mutable,dynamic,growable,no slicing
d={101:"ak",102:"bk",103:"ck"}
print(type(d))
print(d)
print(d.keys())
print(d.values())

#2ways
d={}
d[100]="asd"
d["name"]="ak"
print(d)
d["name","name"]="bk","jk"
print(d)
########
d={1:"a",1:"b"}
d[1]="c"
print(d)
# Out:
# <class 'dict'>
# {101: 'ak', 102: 'bk', 103: 'ck'}
# dict_keys([101, 102, 103])
# dict_values(['ak', 'bk', 'ck'])
# {100: 'asd', 'name': 'ak'}
# {100: 'asd', 'name': 'ak', ('name', 'name'): ('bk', 'jk')}
# {1: 'c'}

# %%
####
d={}
for i in range(3):
  # 1way

  #  k=input("enter key")
  #  v=input("enter value")
  #  d[k]=v

  # 2 way

   d[input("enter key")]=input("enter value")
print(d)

for i in d:
  print(i,d[i])
# Out:
# enter value1
# enter key4
# enter value5
# enter key6
# enter value7
# enter key9
# {'4': '1', '6': '5', '9': '7'}
# 4 1
# 6 5
# 9 7

# %%
#delete dict
d={101:"ak",102:"bk",103:"ck"}
del d[101]
print(d)
# del d delete
d.clear()
print(d)
# print(d)
# Out:
# {102: 'bk', 103: 'ck'}
# {}

# %%
#dict function
#get function (key value)
#
d={100:"ask",101:"sd",102:"asd"}
print(d.get(100))
print(d.get(10,"guest"))

#pop
d.pop(100)
d


###keys#
for i in d.keys():
  print(i)
###values#
for i in d.values():
  print(i)
# Out:
# ask
# guest
# 101
# 102
# sd
# asd

# %%
#items return both keys and values
d={1:"a",2:'bv',3:'c'}
for k,v in d.items():
  print(k,v)
# Out:
# 1 a
# 2 bv
# 3 c

# %%
#copy
d1=d.copy()
print(d1)
# Out:
# {1: 'a', 2: 'bv', 3: 'c'}

# %%
d={}
num=int(input("enter no of elements"))
sum=0
for i in range(num):
  k=input("enter key")
  v=int(input("enter values"))
  d[k]=v
  sum+=v

print(d)
print(sum)
# Out:
# enter no of elements2
# enter keya
# enter values4
# enter key1
# enter values5
# {'a': 4, '1': 5}
# 9

# %%
##############function###########
def fun(a,b):
   return a+b

if __name__ == '_main_':
   print(fun(10,20))

# %%
def add(a,b):
  return a+b

a=int(input("enter no"))
b=int(input("enter no"))
print(add(a,b))
# Out:
# enter no1
# enter no2
# 3

# %%
def arithmatic(a,b):
  return a+b,a-b,a*b,a/b

a=int(input("enter no"))
b=int(input("enter no"))
r1,r2,r3,r4=arithmatic(a,b)
print("add",r1,"sub:",r2,"mult:",r3,"div:",r4)
# Out:
# enter no1
# enter no4
# add 5 sub: -3 mult: 4 div: 0.25

# %%
#lamda function
a=lambda x:x*x*x
print(a(5))
# Out:
# 125

# %%
# varialbe length argument (input in form of tuples)
# var-args methods in java
def show(*n):
  print(n,a)

show(10,20,30)
show(10,20,30,40)
# Out:
# <function <lambda> at 0x79bc7ba16290>
# (10, 20, 30) 9
# (10, 20, 30, 40) 9

# %%
# local and global variable
a=10
def show():
  a=20
  print(a)

show()
print(a)
# Out:
# 20
# 10

# %%
# anonymous function is said to be lambda function
a = lambda x:x*x
print(a(5))
# Out:
# 25

# %%
#additon lamda function
a=lambda x,y:x+y
print(a(10,20))
# Out:
# 30

# %%
#greater no lamda
a=lambda x,y:x if x>y else y
print(a(10,20))
# Out:
# 20

# %%
# greater no among 4
a=lambda x,y,z:x if x>y and x>z else y if y>z else z
print(a(10,20,30))
